# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 500px; float: left;">
#         <h1>Ingenieurinformatik – Übung</h1>
#         Lehrstuhl <b>Computational Civil Engineering</b><br>
#         Kontakt: <a href = "mailto: cce-inginf@uni-wuppertal.de">Email senden</a> | Individuelle Kontakte siehe Webseite des Lehrstuhls<br>
#         Links:
#         <a href="cce.uni-wuppertal.de/inginf">Vorlesungsskript</a> |
#         <a href="cce.uni-wuppertal.de/">Webseite des Lehrstuhls</a>
#     </div>
#     <div style="float:right;">
#         <img src="logo_cce_combined.png" style="width:150px;"/>
#     </div>
# </div>

# %% [markdown]
# # Programmablaufpläne

# %% [markdown]
# 1. Erstellen Sie ein Flussdiagramm, welches das Minimum bestimmt
# 2. Erstelle Sieein Flussdiagramm, welches das Minimum aller positiven Zahlen bestimmt
# 3. Erstelle Sie EIN Flussdiagramm, welches sowohl Minimum aller positiven Zahlen als auch Maximum aller negativen Zahlen zurueck gibt

# %% [markdown]
# ### Lösungsvorschlag
# ```{toggle}
#
# <u>Zu 1.</u>
#
# | ![Beispiel](alg_findmin.svg) |
# | :-: |
# | Möglicher Programmlaufplan zur Bestimmung des Minumums |
#
# <u>Zu 2.</u>
#
#
# | ![Beispiel](alg_findmin_positive.svg) |
# | :-: |
# | Möglicher Programmlaufplan zur Bestimmung des Minumum aller positiven Zahlen |
#
# <u>Zu 3.</u>
#
# | ![Beispiel](alg_find_minpositive_maxnegative.svg) |
# | :-: |
# | Möglicher Programmlaufplan zur Bestimmung Minimum aller positiven Zahlen als auch Maximum aller negativen Zahlen |
#
# ```
